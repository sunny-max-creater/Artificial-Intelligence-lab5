# %% [markdown]
# ## 数据读取与处理

# %%
# !pip install -q transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 78.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 29.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 89.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 71.1 MB/s eta 0:00:00

# %%
from PIL import Image
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torch.utils.data import Dataset, DataLoader, TensorDataset, random_split

from transformers import AdamW, get_linear_schedule_with_warmup, AutoModel, AutoTokenizer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive

import os
drive.mount('/content/drive', force_remount=True)

# %cd drive/MyDrive/Multimodel/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Multimodel

# %%
# !unzip './data.zip' -d './'
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: ./data/3347.jpg
#   inflating: ./data/3347.txt
#   inflating: ./data/3348.jpg
#   inflating: ./data/3348.txt
#   inflating: ./data/3349.jpg
#   inflating: ./data/3349.txt
#   inflating: ./data/335.jpg
#   inflating: ./data/335.txt
#   inflating: ./data/3350.jpg
#   inflating: ./data/3350.txt
#   inflating: ./data/3351.jpg
#   inflating: ./data/3351.txt
#   inflating: ./data/3352.jpg
#   inflating: ./data/3352.txt
#   inflating: ./data/3353.jpg
#   inflating: ./data/3353.txt
#   inflating: ./data/3354.jpg
#   inflating: ./data/3354.txt
#   inflating: ./data/3355.jpg
#   inflating: ./data/3355.txt
#   inflating: ./data/3356.jpg
#   inflating: ./data/3356.txt
#   inflating: ./data/3357.jpg
#   inflating: ./data/3357.txt
#   inflating: ./data/3358.jpg
#   inflating: ./data/3358.txt
#   inflating: ./data/3359.jpg
#   inflating: ./data/3359.txt
#   inflating: ./data/336.jpg
#   inflating: ./data/336.txt
#   inflating: ./data/3360.jpg
#   inflating: ./data/3360.txt
#   inflating: ./data/3361.jpg
#   inflating: ./data/3361.txt
#   inflating: ./data/3362.jpg
#   inflating: ./data/3362.txt
#   inflating: ./data/3363.jpg
#   inflating: ./data/3363.txt
#   inflating: ./data/3364.jpg
#   inflating: ./data/3364.txt
#   inflating: ./data/3365.jpg
#   inflating: ./data/3365.txt
#   inflating: ./data/3366.jpg
#   inflating: ./data/3366.txt
#   inflating: ./data/3367.jpg
#   inflating: ./data/3367.txt
#   inflating: ./data/3368.jpg
#   inflating: ./data/3368.txt
#   inflating: ./data/3369.jpg
#   inflating: ./data/3369.txt
#   inflating: ./data/337.jpg
#   inflating: ./data/337.txt
#   inflating: ./data/3370.jpg
#   inflating: ./data/3370.txt
#   inflating: ./data/3371.jpg
#   inflating: ./data/3371.txt
#   inflating: ./data/3372.jpg
#   inflating: ./data/3372.txt
#   inflating: ./data/3373.jpg
#   inflating: ./data/3373.txt
#   inflating: ./data/3374.jpg
#   inflating: ./data/3374.txt
#   inflating: ./data/3375.jpg
#   inflating: ./data/3375.txt
#   inflating: ./data/3376.jpg
#   inflating: ./data/3376.txt
#   inflating: ./data/3377.jpg
#   inflating: ./data/3377.txt
#   inflating: ./data/3378.jpg
#   inflating: ./data/3378.txt
#   inflating: ./data/3379.jpg
#   inflating: ./data/3379.txt
#   inflating: ./data/338.jpg
#   inflating: ./data/338.txt
#   inflating: ./data/3380.jpg
#   inflating: ./data/3380.txt
#   inflating: ./data/3381.jpg
#   inflating: ./data/3381.txt
#   inflating: ./data/3382.jpg
#   inflating: ./data/3382.txt
#   inflating: ./data/3383.jpg
#   inflating: ./data/3383.txt
#   inflating: ./data/3384.jpg
#   inflating: ./data/3384.txt
#   inflating: ./data/3385.jpg
#   inflating: ./data/3385.txt
#   inflating: ./data/3386.jpg
#   inflating: ./data/3386.txt
#   inflating: ./data/3387.jpg
#   inflating: ./data/3387.txt
#   inflating: ./data/3388.jpg
#   inflating: ./data/3388.txt
#   inflating: ./data/3389.jpg
#   inflating: ./data/3389.txt
#   inflating: ./data/339.jpg
#   inflating: ./data/339.txt
#   inflating: ./data/3390.jpg
#   inflating: ./data/3390.txt
#   inflating: ./data/3391.jpg
#   inflating: ./data/3391.txt
#   inflating: ./data/3392.jpg
#   inflating: ./data/3392.txt
#   inflating: ./data/3393.jpg
#   inflating: ./data/3393.txt
#   inflating: ./data/3394.jpg
#   inflating: ./data/3394.txt
#   inflating: ./data/3395.jpg
#   inflating: ./data/3395.txt
#   inflating: ./data/3396.jpg
#   inflating: ./data/3396.txt
#   inflating: ./data/3397.jpg
#   inflating: ./data/3397.txt
#   inflating: ./data/3398.jpg
#   inflating: ./data/3398.txt
#   inflating: ./data/3399.jpg
#   inflating: ./data/3399.txt
#   inflating: ./data/34.jpg
#   inflating: ./data/34.txt
#   inflating: ./data/340.jpg
#   inflating: ./data/340.txt
#   inflating: ./data/3400.jpg
#   inflating: ./data/3400.txt
#   inflating: ./data/3401.jpg
#   inflating: ./data/3401.txt
#   inflating: ./data/3402.jpg
#   inflating: ./data/3402.txt
#   inflating: ./data/3403.jpg
#   inflating: ./data/3403.txt
#   inflating: ./data/3404.jpg
#   inflating: ./data/3404.txt
#   inflating: ./data/3405.jpg
#   inflating: ./data/3405.txt
#   inflating: ./data/3406.jpg
#   inflating: ./data/3406.txt
#   inflating: ./data/3407.jpg
#   inflating: ./data/3407.txt
#   inflating: ./data/3408.jpg
#   inflating: ./data/3408.txt
#   inflating: ./data/3409.jpg
#   inflating: ./data/3409.txt
#   inflating: ./data/341.jpg
#   inflating: ./data/341.txt
#   inflating: ./data/3410.jpg
#   inflating: ./data/3410.txt
#   inflating: ./data/3411.jpg
#   inflating: ./data/3411.txt
#   inflating: ./data/3412.jpg
#   inflating: ./data/3412.txt
#   inflating: ./data/3413.jpg
#   inflating: ./data/3413.txt
#   inflating: ./data/3414.jpg
#   inflating: ./data/3414.txt
#   inflating: ./data/3415.jpg
#   inflating: ./data/3415.txt
#   inflating: ./data/3416.jpg
#   inflating: ./data/3416.txt
#   inflating: ./data/3417.jpg
#   inflating: ./data/3417.txt
#   inflating: ./data/3418.jpg
#   inflating: ./data/3418.txt
#   inflating: ./data/3419.jpg
#   inflating: ./data/3419.txt
#   inflating: ./data/342.jpg
#   inflating: ./data/342.txt
#   inflating: ./data/3420.jpg
#   inflating: ./data/3420.txt
#   inflating: ./data/3421.jpg
#   inflating: ./data/3421.txt
#   inflating: ./data/3422.jpg
#   inflating: ./data/3422.txt
#   inflating: ./data/3423.jpg
#   inflating: ./data/3423.txt
#   inflating: ./data/3424.jpg
#   inflating: ./data/3424.txt
#   inflating: ./data/3425.jpg
#   inflating: ./data/3425.txt
#   inflating: ./data/3426.jpg
#   inflating: ./data/3426.txt
#   inflating: ./data/3427.jpg
#   inflating: ./data/3427.txt
#   inflating: ./data/3428.jpg
#   inflating: ./data/3428.txt
#   inflating: ./data/3429.jpg
#   inflating: ./data/3429.txt
#   inflating: ./data/343.jpg
#   inflating: ./data/343.txt
#   inflating: ./data/3430.jpg
#   inflating: ./data/3430.txt
#   inflating: ./data/3431.jpg
#   inflating: ./data/3431.txt
#   inflating: ./data/3432.jpg
#   inflating: ./data/3432.txt
#   inflating: ./data/3433.jpg
#   inflating: ./data/3433.txt
#   inflating: ./data/3434.jpg
#   inflating: ./data/3434.txt
#   inflating: ./data/3435.jpg
#   inflating: ./data/3435.txt
#   inflating: ./data/3436.jpg
#   inflating: ./data/3436.txt
#   inflating: ./data/3437.jpg
#   inflating: ./data/3437.txt
#   inflating: ./data/3439.jpg
#   inflating: ./data/3439.txt
#   inflating: ./data/344.jpg
#   inflating: ./data/344.txt
#   inflating: ./data/3440.jpg
#   inflating: ./data/3440.txt
#   inflating: ./data/3441.jpg
#   inflating: ./data/3441.txt
#   inflating: ./data/3442.jpg
#   inflating: ./data/3442.txt
#   inflating: ./data/3443.jpg
#   inflating: ./data/3443.txt
#   inflating: ./data/3444.jpg
#   inflating: ./data/3444.txt
#   inflating: ./data/3445.jpg
#   inflating: ./data/3445.txt
#   inflating: ./data/3446.jpg
#   inflating: ./data/3446.txt
#   inflating: ./data/3447.jpg
#   inflating: ./data/3447.txt
#   inflating: ./data/3448.jpg
#   inflating: ./data/3448.txt
#   inflating: ./data/3449.jpg
#   inflating: ./data/3449.txt
#   inflating: ./data/345.jpg
#   inflating: ./data/345.txt
#   inflating: ./data/3450.jpg
#   inflating: ./data/3450.txt
#   inflating: ./data/3451.jpg
#   inflating: ./data/3451.txt
#   inflating: ./data/3452.jpg
#   inflating: ./data/3452.txt
#   inflating: ./data/3453.jpg
#   inflating: ./data/3453.txt
#   inflating: ./data/3454.jpg
#   inflating: ./data/3454.txt
#   inflating: ./data/3455.jpg
#   inflating: ./data/3455.txt
#   inflating: ./data/3456.jpg
#   inflating: ./data/3456.txt
#   inflating: ./data/3457.jpg
#   inflating: ./data/3457.txt
#   inflating: ./data/3458.jpg
#   inflating: ./data/3458.txt
#   inflating: ./data/3459.jpg
#   inflating: ./data/3459.txt
#   inflating: ./data/346.jpg
#   inflating: ./data/346.txt
#   inflating: ./data/3460.jpg
#   inflating: ./data/3460.txt
#   inflating: ./data/3461.jpg
#   inflating: ./data/3461.txt
#   inflating: ./data/3462.jpg
#   inflating: ./data/3462.txt
#   inflating: ./data/3463.jpg
#   inflating: ./data/3463.txt
#   inflating: ./data/3464.jpg
#   inflating: ./data/3464.txt
#   inflating: ./data/3465.jpg
#   inflating: ./data/3465.txt
#   inflating: ./data/3466.jpg
#   inflating: ./data/3466.txt
#   inflating: ./data/3467.jpg
#   inflating: ./data/3467.txt
#   inflating: ./data/3468.jpg
#   inflating: ./data/3468.txt
#   inflating: ./data/3469.jpg
#   inflating: ./data/3469.txt
#   inflating: ./data/347.jpg
#   inflating: ./data/347.txt
#   inflating: ./data/3470.jpg
#   inflating: ./data/3470.txt
#   inflating: ./data/3472.jpg
#   inflating: ./data/3472.txt
#   inflating: ./data/3473.jpg
#   inflating: ./data/3473.txt
#   inflating: ./data/3474.jpg
#   inflating: ./data/3474.txt
#   inflating: ./data/3475.jpg
#   inflating: ./data/3475.txt
#   inflating: ./data/3476.jpg
#   inflating: ./data/3476.txt
#   inflating: ./data/3477.jpg
#   inflating: ./data/3477.txt
#   inflating: ./data/3478.jpg
#   inflating: ./data/3478.txt
#   inflating: ./data/3479.jpg
#   inflating: ./data/3479.txt
#   inflating: ./data/348.jpg
#   inflating: ./data/348.txt
#   inflating: ./data/3480.jpg
#   inflating: ./data/3480.txt
#   inflating: ./data/3481.jpg
#   inflating: ./data/3481.txt
#   inflating: ./data/3482.jpg
#   inflating: ./data/3482.txt
#   inflating: ./data/3483.jpg
#   inflating: ./data/3483.txt
#   inflating: ./data/3484.jpg
#   inflating: ./data/3484.txt
#   inflating: ./data/3485.jpg
#   inflating: ./data/3485.txt
#   inflating: ./data/3486.jpg
#   inflating: ./data/3486.txt
#   inflating: ./data/3487.jpg
#   inflating: ./data/3487.txt
#   inflating: ./data/3488.jpg
#   inflating: ./data/3488.txt
#   inflating: ./data/3489.jpg
#   inflating: ./data/3489.txt
#   inflating: ./data/349.jpg
#   inflating: ./data/349.txt
#   inflating: ./data/3490.jpg
#   inflating: ./data/3490.txt
#   inflating: ./data/3491.jpg
#   inflating: ./data/3491.txt
#   inflating: ./data/3492.jpg
#   inflating: ./data/3492.txt
#   inflating: ./data/3493.jpg
#   inflating: ./data/3493.txt
#   inflating: ./data/3494.jpg
#   inflating: ./data/3494.txt
#   inflating: ./data/3495.jpg
#   inflating: ./data/3495.txt
#   inflating: ./data/3496.jpg
#   inflating: ./data/3496.txt
#   inflating: ./data/3497.jpg
#   inflating: ./data/3497.txt
#   inflating: ./data/3498.jpg
#   inflating: ./data/3498.txt
#   inflating: ./data/3499.jpg
#   inflating: ./data/3499.txt
#   inflating: ./data/35.jpg
#   inflating: ./data/35.txt
#   inflating: ./data/350.jpg
#   inflating: ./data/350.txt
#   inflating: ./data/3500.jpg
#   inflating: ./data/3500.txt
#   inflating: ./data/3501.jpg
#   inflating: ./data/3501.txt
#   inflating: ./data/3502.jpg
#   inflating: ./data/3502.txt
#   inflating: ./data/3503.jpg
#   inflating: ./data/3503.txt
#   inflating: ./data/3504.jpg
#   inflating: ./data/3504.txt
#   inflating: ./data/3505.jpg
#   inflating: ./data/3505.txt
#   inflating: ./data/3506.jpg
#   inflating: ./data/3506.txt
#   inflating: ./data/3507.jpg
#   inflating: ./data/3507.txt
#   inflating: ./data/3508.jpg
#   inflating: ./data/3508.txt
#   inflating: ./data/3509.jpg
#   inflating: ./data/3509.txt
#   inflating: ./data/351.jpg
#   inflating: ./data/351.txt
#   inflating: ./data/3510.jpg
#   inflating: ./data/3510.txt
#   inflating: ./data/3511.jpg
#   inflating: ./data/3511.txt
#   inflating: ./data/3512.jpg
#   inflating: ./data/3512.txt
#   inflating: ./data/3513.jpg
#   inflating: ./data/3513.txt
#   inflating: ./data/3515.jpg
#   inflating: ./data/3515.txt
#   inflating: ./data/3516.jpg
#   inflating: ./data/3516.txt
#   inflating: ./data/3517.jpg
#   inflating: ./data/3517.txt
#   inflating: ./data/352.jpg
#   inflating: ./data/352.txt
#   inflating: ./data/3520.jpg
#   inflating: ./data/3520.txt
#   inflating: ./data/3521.jpg
#   inflating: ./data/3521.txt
#   inflating: ./data/3522.jpg
#   inflating: ./data/3522.txt
#   inflating: ./data/3523.jpg
#   inflating: ./data/3523.txt
#   inflating: ./data/3524.jpg
#   inflating: ./data/3524.txt
#   inflating: ./data/3525.jpg
#   inflating: ./data/3525.txt
#   inflating: ./data/3526.jpg
#   inflating: ./data/3526.txt
#   inflating: ./data/3527.jpg
#   inflating: ./data/3527.txt
#   inflating: ./data/3528.jpg
#   inflating: ./data/3528.txt
#   inflating: ./data/3529.jpg
#   inflating: ./data/3529.txt
#   inflating: ./data/353.jpg
#   inflating: ./data/353.txt
#   inflating: ./data/3530.jpg
#   inflating: ./data/3530.txt
#   inflating: ./data/3531.jpg
#   inflating: ./data/3531.txt
#   inflating: ./data/3532.jpg
#   inflating: ./data/3532.txt
#   inflating: ./data/3533.jpg
#   inflating: ./data/3533.txt
#   inflating: ./data/3534.jpg
#   inflating: ./data/3534.txt
#   inflating: ./data/3535.jpg
#   inflating: ./data/3535.txt
#   inflating: ./data/3536.jpg
#   inflating: ./data/3536.txt
#   inflating: ./data/3537.jpg
#   inflating: ./data/3537.txt
#   inflating: ./data/3538.jpg
#   inflating: ./data/3538.txt
#   inflating: ./data/3539.jpg
#   inflating: ./data/3539.txt
#   inflating: ./data/354.jpg
#   inflating: ./data/354.txt
#   inflating: ./data/3540.jpg
#   inflating: ./data/3540.txt
#   inflating: ./data/3541.jpg
#   inflating: ./data/3541.txt
#   inflating: ./data/3542.jpg
#   inflating: ./data/3542.txt
#   inflating: ./data/3543.jpg
#   inflating: ./data/3543.txt
#   inflating: ./data/3544.jpg
#   inflating: ./data/3544.txt
#   inflating: ./data/3545.jpg
#   inflating: ./data/3545.txt
#   inflating: ./data/3546.jpg
#   inflating: ./data/3546.txt
#   inflating: ./data/3547.jpg
#   inflating: ./data/3547.txt
#   inflating: ./data/3548.jpg
#   inflating: ./data/3548.txt
#   inflating: ./data/3549.jpg
#   inflating: ./data/3549.txt
#   inflating: ./data/355.jpg
#   inflating: ./data/355.txt
#   inflating: ./data/3550.jpg
#   inflating: ./data/3550.txt
#   inflating: ./data/3551.jpg
#   inflating: ./data/3551.txt
#   inflating: ./data/3552.jpg
#   inflating: ./data/3552.txt
#   inflating: ./data/3553.jpg
#   inflating: ./data/3553.txt
#   inflating: ./data/3554.jpg
#   inflating: ./data/3554.txt
#   inflating: ./data/3555.jpg
#   inflating: ./data/3555.txt
#   inflating: ./data/3556.jpg
#   inflating: ./data/3556.txt
#   inflating: ./data/3557.jpg
#   inflating: ./data/3557.txt
#   inflating: ./data/3558.jpg
#   inflating: ./data/3558.txt
#   inflating: ./data/3559.jpg
#   inflating: ./data/3559.txt
#   inflating: ./data/356.jpg
#   inflating: ./data/356.txt
#   inflating: ./data/3560.jpg
#   inflating: ./data/3560.txt
#   inflating: ./data/3561.jpg
#   inflating: ./data/3561.txt
#   inflating: ./data/3562.jpg
#   inflating: ./data/3562.txt
#   inflating: ./data/3563.jpg
#   inflating: ./data/3563.txt
#   inflating: ./data/3564.jpg
#   inflating: ./data/3564.txt
#   inflating: ./data/3565.jpg
#   inflating: ./data/3565.txt
#   inflating: ./data/3566.jpg
#   inflating: ./data/3566.txt
#   inflating: ./data/3567.jpg
#   inflating: ./data/3567.txt
#   inflating: ./data/3568.jpg
#   inflating: ./data/3568.txt
#   inflating: ./data/3569.jpg
#   inflating: ./data/3569.txt
#   inflating: ./data/357.jpg
#   inflating: ./data/357.txt
#   inflating: ./data/3570.jpg
#   inflating: ./data/3570.txt
#   inflating: ./data/3571.jpg
#   inflating: ./data/3571.txt
#   inflating: ./data/3572.jpg
#   inflating: ./data/3572.txt
#   inflating: ./data/3573.jpg
#   inflating: ./data/3573.txt
#   inflating: ./data/3574.jpg
#   inflating: ./data/3574.txt
#   inflating: ./data/3575.jpg
#   inflating: ./data/3575.txt
#   inflating: ./data/3576.jpg
#   inflating: ./data/3576.txt
#   inflating: ./data/3577.jpg
#   inflating: ./data/3577.txt
#   inflating: ./data/3578.jpg
#   inflating: ./data/3578.txt
#   inflating: ./data/3579.jpg
#   inflating: ./data/3579.txt
#   inflating: ./data/358.jpg
#   inflating: ./data/358.txt
#   inflating: ./data/3580.jpg
#   inflating: ./data/3580.txt
#   inflating: ./data/3581.jpg
#   inflating: ./data/3581.txt
#   inflating: ./data/3582.jpg
#   inflating: ./data/3582.txt
#   inflating: ./data/3583.jpg
#   inflating: ./data/3583.txt
#   inflating: ./data/3584.jpg
#   inflating: ./data/3584.txt
#   inflating: ./data/3585.jpg
#   inflating: ./data/3585.txt
#   inflating: ./data/3586.jpg
#   inflating: ./data/3586.txt
#   inflating: ./data/3587.jpg
#   inflating: ./data/3587.txt
#   inflating: ./data/3588.jpg
#   inflating: ./data/3588.txt
#   inflating: ./data/3589.jpg
#   inflating: ./data/3589.txt
#   inflating: ./data/359.jpg
#   inflating: ./data/359.txt
#   inflating: ./data/3590.jpg
#   inflating: ./data/3590.txt
#   inflating: ./data/3591.jpg
#   inflating: ./data/3591.txt
#   inflating: ./data/3592.jpg
#   inflating: ./data/3592.txt
#   inflating: ./data/3593.jpg
#   inflating: ./data/3593.txt
#   inflating: ./data/3594.jpg
#   inflating: ./data/3594.txt
#   inflating: ./data/3595.jpg
#   inflating: ./data/3595.txt
#   inflating: ./data/3596.jpg
#   inflating: ./data/3596.txt
#   inflating: ./data/3597.jpg
#   inflating: ./data/3597.txt
#   inflating: ./data/3598.jpg
#   inflating: ./data/3598.txt
#   inflating: ./data/3599.jpg
#   inflating: ./data/3599.txt
#   inflating: ./data/36.jpg
#   inflating: ./data/36.txt
#   inflating: ./data/360.jpg
#   inflating: ./data/360.txt
#   inflating: ./data/3600.jpg
#   inflating: ./data/3600.txt
#   inflating: ./data/3601.jpg
#   inflating: ./data/3601.txt
#   inflating: ./data/3602.jpg
#   inflating: ./data/3602.txt
#   inflating: ./data/3603.jpg
#   inflating: ./data/3603.txt
#   inflating: ./data/3604.jpg
#   inflating: ./data/3604.txt
#   inflating: ./data/3605.jpg
#   inflating: ./data/3605.txt
#   inflating: ./data/3606.jpg
#   inflating: ./data/3606.txt
#   inflating: ./data/3607.jpg
#   inflating: ./data/3607.txt
#   inflating: ./data/3608.jpg
#   inflating: ./data/3608.txt
#   inflating: ./data/3609.jpg
#   inflating: ./data/3609.txt
#   inflating: ./data/361.jpg
#   inflating: ./data/361.txt
#   inflating: ./data/3610.jpg
#   inflating: ./data/3610.txt
#   inflating: ./data/3611.jpg
#   inflating: ./data/3611.txt
#   inflating: ./data/3612.jpg
#   inflating: ./data/3612.txt
#   inflating: ./data/3613.jpg
#   inflating: ./data/3613.txt
#   inflating: ./data/3614.jpg
#   inflating: ./data/3614.txt
#   inflating: ./data/3615.jpg
#   inflating: ./data/3615.txt
#   inflating: ./data/3616.jpg
#   inflating: ./data/3616.txt
#   inflating: ./data/3617.jpg
#   inflating: ./data/3617.txt
#   inflating: ./data/3618.jpg
#   inflating: ./data/3618.txt
#   inflating: ./data/3619.jpg
#   inflating: ./data/3619.txt
#   inflating: ./data/362.jpg
#   inflating: ./data/362.txt
#   inflating: ./data/3620.jpg
#   inflating: ./data/3620.txt
#   inflating: ./data/3621.jpg
#   inflating: ./data/3621.txt
#   inflating: ./data/3622.jpg
#   inflating: ./data/3622.txt
#   inflating: ./data/3623.jpg
#   inflating: ./data/3623.txt
#   inflating: ./data/3624.jpg
#   inflating: ./data/3624.txt
#   inflating: ./data/3625.jpg
#   inflating: ./data/3625.txt
#   inflating: ./data/3626.jpg
#   inflating: ./data/3626.txt
#   inflating: ./data/3627.jpg
#   inflating: ./data/3627.txt
#   inflating: ./data/3628.jpg
#   inflating: ./data/3628.txt
#   inflating: ./data/3629.jpg
#   inflating: ./data/3629.txt
#   inflating: ./data/363.jpg
#   inflating: ./data/363.txt
#   inflating: ./data/3630.jpg
#   inflating: ./data/3630.txt
#   inflating: ./data/3631.jpg
#   inflating: ./data/3631.txt
#   inflating: ./data/3632.jpg
#   inflating: ./data/3632.txt
#   inflating: ./data/3633.jpg
#   inflating: ./data/3633.txt
#   inflating: ./data/3634.jpg
#   inflating: ./data/3634.txt
#   inflating: ./data/3635.jpg
#   inflating: ./data/3635.txt
#   inflating: ./data/3636.jpg
#   inflating: ./data/3636.txt
#   inflating: ./data/3637.jpg
#   inflating: ./data/3637.txt
#   inflating: ./data/3638.jpg
#   inflating: ./data/3638.txt
#   inflating: ./data/3639.jpg
#   inflating: ./data/3639.txt
#   inflating: ./data/364.jpg
#   inflating: ./data/364.txt
#   inflating: ./data/3640.jpg
#   inflating: ./data/3640.txt
#   inflating: ./data/3641.jpg
#   inflating: ./data/3641.txt
#   inflating: ./data/3642.jpg
#   inflating: ./data/3642.txt
#   inflating: ./data/3643.jpg
#   inflating: ./data/3643.txt
#   inflating: ./data/3644.jpg
#   inflating: ./data/3644.txt
#   inflating: ./data/3645.jpg
#   inflating: ./data/3645.txt
#   inflating: ./data/3646.jpg
#   inflating: ./data/3646.txt
#   inflating: ./data/3647.jpg
#   inflating: ./data/3647.txt
#   inflating: ./data/3648.jpg
#   inflating: ./data/3648.txt
#   inflating: ./data/3649.jpg
#   inflating: ./data/3649.txt
#   inflating: ./data/365.jpg
#   inflating: ./data/365.txt
#   inflating: ./data/3650.jpg
#   inflating: ./data/3650.txt
#   inflating: ./data/3651.jpg
#   inflating: ./data/3651.txt
#   inflating: ./data/3652.jpg
#   inflating: ./data/3652.txt
#   inflating: ./data/3653.jpg
#   inflating: ./data/3653.txt
#   inflating: ./data/3654.jpg
#   inflating: ./data/3654.txt
#   inflating: ./data/3655.jpg
#   inflating: ./data/3655.txt
#   inflating: ./data/3656.jpg
#   inflating: ./data/3656.txt
#   inflating: ./data/3657.jpg
#   inflating: ./data/3657.txt
#   inflating: ./data/3658.jpg
#   inflating: ./data/3658.txt
#   inflating: ./data/3659.jpg
#   inflating: ./data/3659.txt
#   inflating: ./data/366.jpg
#   inflating: ./data/366.txt
#   inflating: ./data/3660.jpg
#   inflating: ./data/3660.txt
#   inflating: ./data/3661.jpg
#   inflating: ./data/3661.txt
#   inflating: ./data/3662.jpg
#   inflating: ./data/3662.txt
#   inflating: ./data/3663.jpg
#   inflating: ./data/3663.txt
#   inflating: ./data/3664.jpg
#   inflating: ./data/3664.txt
#   inflating: ./data/3665.jpg
#   inflating: ./data/3665.txt
#   inflating: ./data/3666.jpg
#   inflating: ./data/3666.txt
#   inflating: ./data/3667.jpg
#   inflating: ./data/3667.txt
#   inflating: ./data/3668.jpg
#   inflating: ./data/3668.txt
#   inflating: ./data/3669.jpg
#   inflating: ./data/3669.txt
#   inflating: ./data/367.jpg
#   inflating: ./data/367.txt
#   inflating: ./data/3670.jpg
#   inflating: ./data/3670.txt
#   inflating: ./data/3671.jpg
#   inflating: ./data/3671.txt
#   inflating: ./data/3672.jpg
#   inflating: ./data/3672.txt
#   inflating: ./data/3673.jpg
#   inflating: ./data/3673.txt
#   inflating: ./data/3674.jpg
#   inflating: ./data/3674.txt
#   inflating: ./data/3675.jpg
#   inflating: ./data/3675.txt
#   inflating: ./data/3676.jpg
#   inflating: ./data/3676.txt
#   inflating: ./data/3677.jpg
#   inflating: ./data/3677.txt
#   inflating: ./data/3678.jpg
#   inflating: ./data/3678.txt
#   inflating: ./data/3679.jpg
#   inflating: ./data/3679.txt
#   inflating: ./data/368.jpg
#   inflating: ./data/368.txt
#   inflating: ./data/3680.jpg
#   inflating: ./data/3680.txt
#   inflating: ./data/3681.jpg
#   inflating: ./data/3681.txt
#   inflating: ./data/3682.jpg
#   inflating: ./data/3682.txt
#   inflating: ./data/3684.jpg
#   inflating: ./data/3684.txt
#   inflating: ./data/3685.jpg
#   inflating: ./data/3685.txt
#   inflating: ./data/3686.jpg
#   inflating: ./data/3686.txt
#   inflating: ./data/3687.jpg
#   inflating: ./data/3687.txt
#   inflating: ./data/3688.jpg
#   inflating: ./data/3688.txt
#   inflating: ./data/3689.jpg
#   inflating: ./data/3689.txt
#   inflating: ./data/369.jpg
#   inflating: ./data/369.txt
#   inflating: ./data/3690.jpg
#   inflating: ./data/3690.txt
#   inflating: ./data/3691.jpg
#   inflating: ./data/3691.txt
#   inflating: ./data/3692.jpg
#   inflating: ./data/3692.txt
#   inflating: ./data/3693.jpg
#   inflating: ./data/3693.txt
#   inflating: ./data/3694.jpg
#   inflating: ./data/3694.txt
#   inflating: ./data/3695.jpg
#   inflating: ./data/3695.txt
#   inflating: ./data/3696.jpg
#   inflating: ./data/3696.txt
#   inflating: ./data/3697.jpg
#   inflating: ./data/3697.txt
#   inflating: ./data/3698.jpg
#   inflating: ./data/3698.txt
#   inflating: ./data/3699.jpg
#   inflating: ./data/3699.txt
#   inflating: ./data/37.jpg
#   inflating: ./data/37.txt
#   inflating: ./data/370.jpg
#   inflating: ./data/370.txt
#   inflating: ./data/3700.jpg
#   inflating: ./data/3700.txt
#   inflating: ./data/3701.jpg
#   inflating: ./data/3701.txt
#   inflating: ./data/3703.jpg
#   inflating: ./data/3703.txt
#   inflating: ./data/3704.jpg
#   inflating: ./data/3704.txt
#   inflating: ./data/3705.jpg
#   inflating: ./data/3705.txt
#   inflating: ./data/3706.jpg
#   inflating: ./data/3706.txt
#   inflating: ./data/3708.jpg
#   inflating: ./data/3708.txt
#   inflating: ./data/3709.jpg
#   inflating: ./data/3709.txt
#   inflating: ./data/371.jpg
#   inflating: ./data/371.txt
#   inflating: ./data/3710.jpg
#   inflating: ./data/3710.txt
#   inflating: ./data/3711.jpg
#   inflating: ./data/3711.txt
#   inflating: ./data/3712.jpg
#   inflating: ./data/3712.txt
#   inflating: ./data/3713.jpg
#   inflating: ./data/3713.txt
#   inflating: ./data/3714.jpg
#   inflating: ./data/3714.txt
#   inflating: ./data/3715.jpg
#   inflating: ./data/3715.txt
#   inflating: ./data/3716.jpg
#   inflating: ./data/3716.txt
#   inflating: ./data/3717.jpg
#   inflating: ./data/3717.txt
#   inflating: ./data/3718.jpg
#   inflating: ./data/3718.txt
#   inflating: ./data/3719.jpg
#   inflating: ./data/3719.txt
#   inflating: ./data/372.jpg
#   inflating: ./data/372.txt
#   inflating: ./data/3720.jpg
#   inflating: ./data/3720.txt
#   inflating: ./data/3721.jpg
#   inflating: ./data/3721.txt
#   inflating: ./data/3722.jpg
#   inflating: ./data/3722.txt
#   inflating: ./data/3723.jpg
#   inflating: ./data/3723.txt
#   inflating: ./data/3724.jpg
#   inflating: ./data/3724.txt
#   inflating: ./data/3725.jpg
#   inflating: ./data/3725.txt
#   inflating: ./data/3726.jpg
#   inflating: ./data/3726.txt
#   inflating: ./data/3727.jpg
#   inflating: ./data/3727.txt
#   inflating: ./data/3728.jpg
#   inflating: ./data/3728.txt
#   inflating: ./data/3729.jpg
#   inflating: ./data/3729.txt
#   inflating: ./data/373.jpg
#   inflating: ./data/373.txt
#   inflating: ./data/3730.jpg
#   inflating: ./data/3730.txt
#   inflating: ./data/3731.jpg
#   inflating: ./data/3731.txt
#   inflating: ./data/3732.jpg
#   inflating: ./data/3732.txt
#   inflating: ./data/3733.jpg
#   inflating: ./data/3733.txt
#   inflating: ./data/3734.jpg
#   inflating: ./data/3734.txt
#   inflating: ./data/3735.jpg
#   inflating: ./data/3735.txt
#   inflating: ./data/3736.jpg
#   inflating: ./data/3736.txt
#   inflating: ./data/3737.jpg
#   inflating: ./data/3737.txt
#   inflating: ./data/3738.jpg
#   inflating: ./data/3738.txt
#   inflating: ./data/374.jpg
#   inflating: ./data/374.txt
#   inflating: ./data/3740.jpg
#   inflating: ./data/3740.txt
#   inflating: ./data/3741.jpg
#   inflating: ./data/3741.txt
#   inflating: ./data/3742.jpg
#   inflating: ./data/3742.txt
#   inflating: ./data/3743.jpg
#   inflating: ./data/3743.txt
#   inflating: ./data/3744.jpg
#   inflating: ./data/3744.txt
#   inflating: ./data/3745.jpg
#   inflating: ./data/3745.txt
#   inflating: ./data/3747.jpg
#   inflating: ./data/3747.txt
#   inflating: ./data/3748.jpg
#   inflating: ./data/3748.txt
#   inflating: ./data/3749.jpg
#   inflating: ./data/3749.txt
#   inflating: ./data/375.jpg
#   inflating: ./data/375.txt
#   inflating: ./data/3750.jpg
#   inflating: ./data/3750.txt
#   inflating: ./data/3752.jpg
#   inflating: ./data/3752.txt
#   inflating: ./data/3753.jpg
#   inflating: ./data/3753.txt
#   inflating: ./data/3754.jpg
#   inflating: ./data/3754.txt
#   inflating: ./data/3755.jpg
#   inflating: ./data/3755.txt
#   inflating: ./data/3756.jpg
#   inflating: ./data/3756.txt
#   inflating: ./data/3758.jpg
#   inflating: ./data/3758.txt
#   inflating: ./data/3759.jpg
#   inflating: ./data/3759.txt
#   inflating: ./data/376.jpg
#   inflating: ./data/376.txt
#   inflating: ./data/3760.jpg
#   inflating: ./data/3760.txt
#   inflating: ./data/3761.jpg
#   inflating: ./data/3761.txt
#   inflating: ./data/3762.jpg
#   inflating: ./data/3762.txt
#   inflating: ./data/3763.jpg
#   inflating: ./data/3763.txt
#   inflating: ./data/3764.jpg
#   inflating: ./data/3764.txt
#   inflating: ./data/3765.jpg
#   inflating: ./data/3765.txt
#   inflating: ./data/3766.jpg
#   inflating: ./data/3766.txt
#   inflating: ./data/3767.jpg
#   inflating: ./data/3767.txt
#   inflating: ./data/3768.jpg
#   inflating: ./data/3768.txt
#   inflating: ./data/3769.jpg
#   inflating: ./data/3769.txt
#   inflating: ./data/377.jpg
#   inflating: ./data/377.txt
#   inflating: ./data/3770.jpg
#   inflating: ./data/3770.txt
#   inflating: ./data/3771.jpg
#   inflating: ./data/3771.txt
#   inflating: ./data/3772.jpg
#   inflating: ./data/3772.txt
#   inflating: ./data/3773.jpg
#   inflating: ./data/3773.txt
#   inflating: ./data/3774.jpg
#   inflating: ./data/3774.txt
#   inflating: ./data/3775.jpg
#   inflating: ./data/3775.txt
#   inflating: ./data/3776.jpg
#   inflating: ./data/3776.txt
#   inflating: ./data/3777.jpg
#   inflating: ./data/3777.txt
#   inflating: ./data/3778.jpg
#   inflating: ./data/3778.txt
#   inflating: ./data/3779.jpg
#   inflating: ./data/3779.txt
#   inflating: ./data/378.jpg
#   inflating: ./data/378.txt
#   inflating: ./data/3780.jpg
#   inflating: ./data/3780.txt
#   inflating: ./data/3781.jpg
#   inflating: ./data/3781.txt
#   inflating: ./data/3782.jpg
#   inflating: ./data/3782.txt
#   inflating: ./data/3783.jpg
#   inflating: ./data/3783.txt
#   inflating: ./data/3784.jpg
#   inflating: ./data/3784.txt
#   inflating: ./data/3785.jpg
#   inflating: ./data/3785.txt
#   inflating: ./data/3786.jpg
#   inflating: ./data/3786.txt
#   inflating: ./data/3787.jpg
#   inflating: ./data/3787.txt
#   inflating: ./data/3788.jpg
#   inflating: ./data/3788.txt
#   inflating: ./data/3789.jpg
#   inflating: ./data/3789.txt
#   inflating: ./data/379.jpg
#   inflating: ./data/379.txt
#   inflating: ./data/3790.jpg
#   inflating: ./data/3790.txt
#   inflating: ./data/3791.jpg
#   inflating: ./data/3791.txt
#   inflating: ./data/3792.jpg
#   inflating: ./data/3792.txt
#   inflating: ./data/3793.jpg
#   inflating: ./data/3793.txt
#   inflating: ./data/3794.jpg
#   inflating: ./data/3794.txt
#   inflating: ./data/3795.jpg
#   inflating: ./data/3795.txt
#   inflating: ./data/3796.jpg
#   inflating: ./data/3796.txt
#   inflating: ./data/3797.jpg
#   inflating: ./data/3797.txt
#   inflating: ./data/3798.jpg
#   inflating: ./data/3798.txt
#   inflating: ./data/3799.jpg
#   inflating: ./data/3799.txt
#   inflating: ./data/38.jpg
#   inflating: ./data/38.txt
#   inflating: ./data/380.jpg
#   inflating: ./data/380.txt
#   inflating: ./data/3800.jpg
#   inflating: ./data/3800.txt
#   inflating: ./data/3801.jpg
#   inflating: ./data/3801.txt
#   inflating: ./data/3802.jpg
#   inflating: ./data/3802.txt
#   inflating: ./data/3805.jpg
#   inflating: ./data/3805.txt
#   inflating: ./data/3806.jpg
#   inflating: ./data/3806.txt
#   inflating: ./data/3807.jpg
#   inflating: ./data/3807.txt
#   inflating: ./data/3808.jpg
#   inflating: ./data/3808.txt
#   inflating: ./data/3809.jpg
#   inflating: ./data/3809.txt
#   inflating: ./data/381.jpg
#   inflating: ./data/381.txt
#   inflating: ./data/3811.jpg
#   inflating: ./data/3811.txt
#   inflating: ./data/3812.jpg
#   inflating: ./data/3812.txt
#   inflating: ./data/3813.jpg
#   inflating: ./data/3813.txt
#   inflating: ./data/3814.jpg
#   inflating: ./data/3814.txt
#   inflating: ./data/3815.jpg
#   inflating: ./data/3815.txt
#   inflating: ./data/3816.jpg
#   inflating: ./data/3816.txt
#   inflating: ./data/3817.jpg
#   inflating: ./data/3817.txt
#   inflating: ./data/3818.jpg
#   inflating: ./data/3818.txt
#   inflating: ./data/3819.jpg
#   inflating: ./data/3819.txt
#   inflating: ./data/382.jpg
#   inflating: ./data/382.txt
#   inflating: ./data/3820.jpg
#   inflating: ./data/3820.txt
#   inflating: ./data/3821.jpg
#   inflating: ./data/3821.txt
#   inflating: ./data/3822.jpg
#   inflating: ./data/3822.txt
#   inflating: ./data/3823.jpg
#   inflating: ./data/3823.txt
#   inflating: ./data/3824.jpg
#   inflating: ./data/3824.txt
#   inflating: ./data/3825.jpg
#   inflating: ./data/3825.txt
#   inflating: ./data/3826.jpg
#   inflating: ./data/3826.txt
#   inflating: ./data/3827.jpg
#   inflating: ./data/3827.txt
#   inflating: ./data/3828.jpg
#   inflating: ./data/3828.txt
#   inflating: ./data/3829.jpg
#   inflating: ./data/3829.txt
#   inflating: ./data/383.jpg
#   inflating: ./data/383.txt
#   inflating: ./data/3830.jpg
#   inflating: ./data/3830.txt
#   inflating: ./data/3831.jpg
#   inflating: ./data/3831.txt
#   inflating: ./data/3832.jpg
#   inflating: ./data/3832.txt
#   inflating: ./data/3833.jpg
#   inflating: ./data/3833.txt
#   inflating: ./data/3834.jpg
#   inflating: ./data/3834.txt
#   inflating: ./data/3835.jpg
#   inflating: ./data/3835.txt
#   inflating: ./data/3836.jpg
#   inflating: ./data/3836.txt
#   inflating: ./data/3837.jpg
#   inflating: ./data/3837.txt
#   inflating: ./data/3838.jpg
#   inflating: ./data/3838.txt
#   inflating: ./data/3839.jpg
#   inflating: ./data/3839.txt
#   inflating: ./data/384.jpg
#   inflating: ./data/384.txt
#   inflating: ./data/3840.jpg
#   inflating: ./data/3840.txt
#   inflating: ./data/3841.jpg
#   inflating: ./data/3841.txt
#   inflating: ./data/3842.jpg
#   inflating: ./data/3842.txt
#   inflating: ./data/3843.jpg
#   inflating: ./data/3843.txt
#   inflating: ./data/3844.jpg
#   inflating: ./data/3844.txt
#   inflating: ./data/3845.jpg
#   inflating: ./data/3845.txt
#   inflating: ./data/3846.jpg
#   inflating: ./data/3846.txt
#   inflating: ./data/3848.jpg
#   inflating: ./data/3848.txt
#   inflating: ./data/3849.jpg
#   inflating: ./data/3849.txt
#   inflating: ./data/385.jpg
#   inflating: ./data/385.txt
#   inflating: ./data/3850.jpg
#   inflating: ./data/3850.txt
#   inflating: ./data/3851.jpg
#   inflating: ./data/3851.txt
#   inflating: ./data/3852.jpg
#   inflating: ./data/3852.txt
#   inflating: ./data/3853.jpg
#   inflating: ./data/3853.txt
#   inflating: ./data/3854.jpg
#   inflating: ./data/3854.txt
#   inflating: ./data/3855.jpg
#   inflating: ./data/3855.txt
#   inflating: ./data/3856.jpg
#   inflating: ./data/3856.txt
#   inflating: ./data/3857.jpg
#   inflating: ./data/3857.txt
#   inflating: ./data/3858.jpg
#   inflating: ./data/3858.txt
#   inflating: ./data/3859.jpg
#   inflating: ./data/3859.txt
#   inflating: ./data/386.jpg
#   inflating: ./data/386.txt
#   inflating: ./data/3860.jpg
#   inflating: ./data/3860.txt
#   inflating: ./data/3861.jpg
#   inflating: ./data/3861.txt
#   inflating: ./data/3862.jpg
#   inflating: ./data/3862.txt
#   inflating: ./data/3863.jpg
#   inflating: ./data/3863.txt
#   inflating: ./data/3864.jpg
#   inflating: ./data/3864.txt
#   inflating: ./data/3865.jpg
#   inflating: ./data/3865.txt
#   inflating: ./data/3866.jpg
#   inflating: ./data/3866.txt
#   inflating: ./data/3867.jpg
#   inflating: ./data/3867.txt
#   inflating: ./data/3868.jpg
#   inflating: ./data/3868.txt
#   inflating: ./data/3869.jpg
#   inflating: ./data/3869.txt
#   inflating: ./data/387.jpg
#   inflating: ./data/387.txt
#   inflating: ./data/3870.jpg
#   inflating: ./data/3870.txt
#   inflating: ./data/3871.jpg
#   inflating: ./data/3871.txt
#   inflating: ./data/3872.jpg
#   inflating: ./data/3872.txt
#   inflating: ./data/3873.jpg
#   inflating: ./data/3873.txt
#   inflating: ./data/3874.jpg
#   inflating: ./data/3874.txt
#   inflating: ./data/3875.jpg
#   inflating: ./data/3875.txt
#   inflating: ./data/3876.jpg
#   inflating: ./data/3876.txt
#   inflating: ./data/3877.jpg
#   inflating: ./data/3877.txt
#   inflating: ./data/3878.jpg
#   inflating: ./data/3878.txt
#   inflating: ./data/3879.jpg
#   inflating: ./data/3879.txt
#   inflating: ./data/388.jpg
#   inflating: ./data/388.txt
#   inflating: ./data/3880.jpg
#   inflating: ./data/3880.txt
#   inflating: ./data/3881.jpg
#   inflating: ./data/3881.txt
#   inflating: ./data/3882.jpg
#   inflating: ./data/3882.txt
#   inflating: ./data/3883.jpg
#   inflating: ./data/3883.txt
#   inflating: ./data/3884.jpg
#   inflating: ./data/3884.txt
#   inflating: ./data/3885.jpg
#   inflating: ./data/3885.txt
#   inflating: ./data/3886.jpg
#   inflating: ./data/3886.txt
#   inflating: ./data/3887.jpg
#   inflating: ./data/3887.txt
#   inflating: ./data/3888.jpg
#   inflating: ./data/3888.txt
#   inflating: ./data/3889.jpg
#   inflating: ./data/3889.txt
#   inflating: ./data/389.jpg
#   inflating: ./data/389.txt
#   inflating: ./data/3890.jpg
#   inflating: ./data/3890.txt
#   inflating: ./data/3891.jpg
#   inflating: ./data/3891.txt
#   inflating: ./data/3892.jpg
#   inflating: ./data/3892.txt
#   inflating: ./data/3893.jpg
#   inflating: ./data/3893.txt
#   inflating: ./data/3894.jpg
#   inflating: ./data/3894.txt
#   inflating: ./data/3896.jpg
#   inflating: ./data/3896.txt
#   inflating: ./data/3897.jpg
#   inflating: ./data/3897.txt
#   inflating: ./data/3898.jpg
#   inflating: ./data/3898.txt
#   inflating: ./data/3899.jpg
#   inflating: ./data/3899.txt
#   inflating: ./data/39.jpg
#   inflating: ./data/39.txt
#   inflating: ./data/390.jpg
#   inflating: ./data/390.txt
#   inflating: ./data/3900.jpg
#   inflating: ./data/3900.txt
#   inflating: ./data/3901.jpg
#   inflating: ./data/3901.txt
#   inflating: ./data/3902.jpg
#   inflating: ./data/3902.txt
#   inflating: ./data/3903.jpg
#   inflating: ./data/3903.txt
#   inflating: ./data/3904.jpg
#   inflating: ./data/3904.txt
#   inflating: ./data/3905.jpg
#   inflating: ./data/3905.txt
#   inflating: ./data/3907.jpg
#   inflating: ./data/3907.txt
#   inflating: ./data/3909.jpg
#   inflating: ./data/3909.txt
#   inflating: ./data/391.jpg
#   inflating: ./data/391.txt
#   inflating: ./data/3910.jpg
#   inflating: ./data/3910.txt
#   inflating: ./data/3911.jpg
#   inflating: ./data/3911.txt
#   inflating: ./data/3912.jpg
#   inflating: ./data/3912.txt
#   inflating: ./data/3913.jpg
#   inflating: ./data/3913.txt
#   inflating: ./data/3914.jpg
#   inflating: ./data/3914.txt
#   inflating: ./data/3915.jpg
#   inflating: ./data/3915.txt
#   inflating: ./data/3916.jpg
#   inflating: ./data/3916.txt
#   inflating: ./data/3917.jpg
#   inflating: ./data/3917.txt
#   inflating: ./data/3918.jpg
#   inflating: ./data/3918.txt
#   inflating: ./data/3919.jpg
#   inflating: ./data/3919.txt
#   inflating: ./data/392.jpg
#   inflating: ./data/392.txt
#   inflating: ./data/3920.jpg
#   inflating: ./data/3920.txt
#   inflating: ./data/3921.jpg
#   inflating: ./data/3921.txt
#   inflating: ./data/3922.jpg
#   inflating: ./data/3922.txt
#   inflating: ./data/3923.jpg
#   inflating: ./data/3923.txt
#   inflating: ./data/3924.jpg
#   inflating: ./data/3924.txt
#   inflating: ./data/3925.jpg
#   inflating: ./data/3925.txt
#   inflating: ./data/3926.jpg
#   inflating: ./data/3926.txt
#   inflating: ./data/3927.jpg
#   inflating: ./data/3927.txt
#   inflating: ./data/3928.jpg
#   inflating: ./data/3928.txt
#   inflating: ./data/3929.jpg
#   inflating: ./data/3929.txt
#   inflating: ./data/393.jpg
#   inflating: ./data/393.txt
#   inflating: ./data/3930.jpg
#   inflating: ./data/3930.txt
#   inflating: ./data/3931.jpg
#   inflating: ./data/3931.txt
# ...
#   inflating: ./data/809.txt
#   inflating: ./data/81.jpg
#   inflating: ./data/81.txt
#   inflating: ./data/810.jpg
#   inflating: ./data/810.txt
#   inflating: ./data/811.jpg
#   inflating: ./data/811.txt
#   inflating: ./data/812.jpg
#   inflating: ./data/812.txt
#   inflating: ./data/813.jpg
#   inflating: ./data/813.txt
#   inflating: ./data/814.jpg
#   inflating: ./data/814.txt
#   inflating: ./data/815.jpg
#   inflating: ./data/815.txt
#   inflating: ./data/816.jpg
#   inflating: ./data/816.txt
#   inflating: ./data/817.jpg
#   inflating: ./data/817.txt
#   inflating: ./data/818.jpg
#   inflating: ./data/818.txt
#   inflating: ./data/819.jpg
#   inflating: ./data/819.txt
#   inflating: ./data/82.jpg
#   inflating: ./data/82.txt
#   inflating: ./data/820.jpg
#   inflating: ./data/820.txt
#   inflating: ./data/821.jpg
#   inflating: ./data/821.txt
#   inflating: ./data/822.jpg
#   inflating: ./data/822.txt
#   inflating: ./data/823.jpg
#   inflating: ./data/823.txt
#   inflating: ./data/824.jpg
#   inflating: ./data/824.txt
#   inflating: ./data/825.jpg
#   inflating: ./data/825.txt
#   inflating: ./data/826.jpg
#   inflating: ./data/826.txt
#   inflating: ./data/827.jpg
#   inflating: ./data/827.txt
#   inflating: ./data/828.jpg
#   inflating: ./data/828.txt
#   inflating: ./data/829.jpg
#   inflating: ./data/829.txt
#   inflating: ./data/83.jpg
#   inflating: ./data/83.txt
#   inflating: ./data/830.jpg
#   inflating: ./data/830.txt
#   inflating: ./data/831.jpg
#   inflating: ./data/831.txt
#   inflating: ./data/832.jpg
#   inflating: ./data/832.txt
#   inflating: ./data/833.jpg
#   inflating: ./data/833.txt
#   inflating: ./data/834.jpg
#   inflating: ./data/834.txt
#   inflating: ./data/835.jpg
#   inflating: ./data/835.txt
#   inflating: ./data/836.jpg
#   inflating: ./data/836.txt
#   inflating: ./data/837.jpg
#   inflating: ./data/837.txt
#   inflating: ./data/838.jpg
#   inflating: ./data/838.txt
#   inflating: ./data/839.jpg
#   inflating: ./data/839.txt
#   inflating: ./data/84.jpg
#   inflating: ./data/84.txt
#   inflating: ./data/840.jpg
#   inflating: ./data/840.txt
#   inflating: ./data/841.jpg
#   inflating: ./data/841.txt
#   inflating: ./data/842.jpg
#   inflating: ./data/842.txt
#   inflating: ./data/843.jpg
#   inflating: ./data/843.txt
#   inflating: ./data/844.jpg
#   inflating: ./data/844.txt
#   inflating: ./data/845.jpg
#   inflating: ./data/845.txt
#   inflating: ./data/846.jpg
#   inflating: ./data/846.txt
#   inflating: ./data/847.jpg
#   inflating: ./data/847.txt
#   inflating: ./data/848.jpg
#   inflating: ./data/848.txt
#   inflating: ./data/849.jpg
#   inflating: ./data/849.txt
#   inflating: ./data/85.jpg
#   inflating: ./data/85.txt
#   inflating: ./data/850.jpg
#   inflating: ./data/850.txt
#   inflating: ./data/851.jpg
#   inflating: ./data/851.txt
#   inflating: ./data/852.jpg
#   inflating: ./data/852.txt
#   inflating: ./data/853.jpg
#   inflating: ./data/853.txt
#   inflating: ./data/854.jpg
#   inflating: ./data/854.txt
#   inflating: ./data/855.jpg
#   inflating: ./data/855.txt
#   inflating: ./data/856.jpg
#   inflating: ./data/856.txt
#   inflating: ./data/857.jpg
#   inflating: ./data/857.txt
#   inflating: ./data/858.jpg
#   inflating: ./data/858.txt
#   inflating: ./data/859.jpg
#   inflating: ./data/859.txt
#   inflating: ./data/86.jpg
#   inflating: ./data/86.txt
#   inflating: ./data/860.jpg
#   inflating: ./data/860.txt
#   inflating: ./data/861.jpg
#   inflating: ./data/861.txt
#   inflating: ./data/862.jpg
#   inflating: ./data/862.txt
#   inflating: ./data/863.jpg
#   inflating: ./data/863.txt
#   inflating: ./data/864.jpg
#   inflating: ./data/864.txt
#   inflating: ./data/865.jpg
#   inflating: ./data/865.txt
#   inflating: ./data/866.jpg
#   inflating: ./data/866.txt
#   inflating: ./data/867.jpg
#   inflating: ./data/867.txt
#   inflating: ./data/868.jpg
#   inflating: ./data/868.txt
#   inflating: ./data/869.jpg
#   inflating: ./data/869.txt
#   inflating: ./data/87.jpg
#   inflating: ./data/87.txt
#   inflating: ./data/870.jpg
#   inflating: ./data/870.txt
#   inflating: ./data/871.jpg
#   inflating: ./data/871.txt
#   inflating: ./data/872.jpg
#   inflating: ./data/872.txt
#   inflating: ./data/873.jpg
#   inflating: ./data/873.txt
#   inflating: ./data/874.jpg
#   inflating: ./data/874.txt
#   inflating: ./data/875.jpg
#   inflating: ./data/875.txt
#   inflating: ./data/876.jpg
#   inflating: ./data/876.txt
#   inflating: ./data/877.jpg
#   inflating: ./data/877.txt
#   inflating: ./data/878.jpg
#   inflating: ./data/878.txt
#   inflating: ./data/879.jpg
#   inflating: ./data/879.txt
#   inflating: ./data/88.jpg
#   inflating: ./data/88.txt
#   inflating: ./data/880.jpg
#   inflating: ./data/880.txt
#   inflating: ./data/881.jpg
#   inflating: ./data/881.txt
#   inflating: ./data/882.jpg
#   inflating: ./data/882.txt
#   inflating: ./data/883.jpg
#   inflating: ./data/883.txt
#   inflating: ./data/884.jpg
#   inflating: ./data/884.txt
#   inflating: ./data/885.jpg
#   inflating: ./data/885.txt
#   inflating: ./data/886.jpg
#   inflating: ./data/886.txt
#   inflating: ./data/887.jpg
#   inflating: ./data/887.txt
#   inflating: ./data/888.jpg
#   inflating: ./data/888.txt
#   inflating: ./data/889.jpg
#   inflating: ./data/889.txt
#   inflating: ./data/89.jpg
#   inflating: ./data/89.txt
#   inflating: ./data/890.jpg
#   inflating: ./data/890.txt
#   inflating: ./data/891.jpg
#   inflating: ./data/891.txt
#   inflating: ./data/892.jpg
#   inflating: ./data/892.txt
#   inflating: ./data/893.jpg
#   inflating: ./data/893.txt
#   inflating: ./data/894.jpg
#   inflating: ./data/894.txt
#   inflating: ./data/895.jpg
#   inflating: ./data/895.txt
#   inflating: ./data/896.jpg
#   inflating: ./data/896.txt
#   inflating: ./data/897.jpg
#   inflating: ./data/897.txt
#   inflating: ./data/898.jpg
#   inflating: ./data/898.txt
#   inflating: ./data/899.jpg
#   inflating: ./data/899.txt
#   inflating: ./data/9.jpg
#   inflating: ./data/9.txt
#   inflating: ./data/90.jpg
#   inflating: ./data/90.txt
#   inflating: ./data/900.jpg
#   inflating: ./data/900.txt
#   inflating: ./data/901.jpg
#   inflating: ./data/901.txt
#   inflating: ./data/902.jpg
#   inflating: ./data/902.txt
#   inflating: ./data/903.jpg
#   inflating: ./data/903.txt
#   inflating: ./data/904.jpg
#   inflating: ./data/904.txt
#   inflating: ./data/905.jpg
#   inflating: ./data/905.txt
#   inflating: ./data/906.jpg
#   inflating: ./data/906.txt
#   inflating: ./data/907.jpg
#   inflating: ./data/907.txt
#   inflating: ./data/908.jpg
#   inflating: ./data/908.txt
#   inflating: ./data/909.jpg
#   inflating: ./data/909.txt
#   inflating: ./data/91.jpg
#   inflating: ./data/91.txt
#   inflating: ./data/910.jpg
#   inflating: ./data/910.txt
#   inflating: ./data/911.jpg
#   inflating: ./data/911.txt
#   inflating: ./data/912.jpg
#   inflating: ./data/912.txt
#   inflating: ./data/913.jpg
#   inflating: ./data/913.txt
#   inflating: ./data/914.jpg
#   inflating: ./data/914.txt
#   inflating: ./data/915.jpg
#   inflating: ./data/915.txt
#   inflating: ./data/916.jpg
#   inflating: ./data/916.txt
#   inflating: ./data/917.jpg
#   inflating: ./data/917.txt
#   inflating: ./data/918.jpg
#   inflating: ./data/918.txt
#   inflating: ./data/919.jpg
#   inflating: ./data/919.txt
#   inflating: ./data/92.jpg
#   inflating: ./data/92.txt
#   inflating: ./data/920.jpg
#   inflating: ./data/920.txt
#   inflating: ./data/921.jpg
#   inflating: ./data/921.txt
#   inflating: ./data/922.jpg
#   inflating: ./data/922.txt
#   inflating: ./data/923.jpg
#   inflating: ./data/923.txt
#   inflating: ./data/924.jpg
#   inflating: ./data/924.txt
#   inflating: ./data/925.jpg
#   inflating: ./data/925.txt
#   inflating: ./data/926.jpg
#   inflating: ./data/926.txt
#   inflating: ./data/927.jpg
#   inflating: ./data/927.txt
#   inflating: ./data/928.jpg
#   inflating: ./data/928.txt
#   inflating: ./data/929.jpg
#   inflating: ./data/929.txt
#   inflating: ./data/93.jpg
#   inflating: ./data/93.txt
#   inflating: ./data/930.jpg
#   inflating: ./data/930.txt
#   inflating: ./data/931.jpg
#   inflating: ./data/931.txt
#   inflating: ./data/932.jpg
#   inflating: ./data/932.txt
#   inflating: ./data/933.jpg
#   inflating: ./data/933.txt
#   inflating: ./data/934.jpg
#   inflating: ./data/934.txt
#   inflating: ./data/935.jpg
#   inflating: ./data/935.txt
#   inflating: ./data/936.jpg
#   inflating: ./data/936.txt
#   inflating: ./data/937.jpg
#   inflating: ./data/937.txt
#   inflating: ./data/938.jpg
#   inflating: ./data/938.txt
#   inflating: ./data/939.jpg
#   inflating: ./data/939.txt
#   inflating: ./data/94.jpg
#   inflating: ./data/94.txt
#   inflating: ./data/940.jpg
#   inflating: ./data/940.txt
#   inflating: ./data/941.jpg
#   inflating: ./data/941.txt
#   inflating: ./data/942.jpg
#   inflating: ./data/942.txt
#   inflating: ./data/943.jpg
#   inflating: ./data/943.txt
#   inflating: ./data/944.jpg
#   inflating: ./data/944.txt
#   inflating: ./data/945.jpg
#   inflating: ./data/945.txt
#   inflating: ./data/946.jpg
#   inflating: ./data/946.txt
#   inflating: ./data/947.jpg
#   inflating: ./data/947.txt
#   inflating: ./data/948.jpg
#   inflating: ./data/948.txt
#   inflating: ./data/949.jpg
#   inflating: ./data/949.txt
#   inflating: ./data/95.jpg
#   inflating: ./data/95.txt
#   inflating: ./data/950.jpg
#   inflating: ./data/950.txt
#   inflating: ./data/951.jpg
#   inflating: ./data/951.txt
#   inflating: ./data/952.jpg
#   inflating: ./data/952.txt
#   inflating: ./data/953.jpg
#   inflating: ./data/953.txt
#   inflating: ./data/954.jpg
#   inflating: ./data/954.txt
#   inflating: ./data/955.jpg
#   inflating: ./data/955.txt
#   inflating: ./data/956.jpg
#   inflating: ./data/956.txt
#   inflating: ./data/957.jpg
#   inflating: ./data/957.txt
#   inflating: ./data/958.jpg
#   inflating: ./data/958.txt
#   inflating: ./data/959.jpg
#   inflating: ./data/959.txt
#   inflating: ./data/96.jpg
#   inflating: ./data/96.txt
#   inflating: ./data/960.jpg
#   inflating: ./data/960.txt
#   inflating: ./data/961.jpg
#   inflating: ./data/961.txt
#   inflating: ./data/962.jpg
#   inflating: ./data/962.txt
#   inflating: ./data/963.jpg
#   inflating: ./data/963.txt
#   inflating: ./data/964.jpg
#   inflating: ./data/964.txt
#   inflating: ./data/965.jpg
#   inflating: ./data/965.txt
#   inflating: ./data/966.jpg
#   inflating: ./data/966.txt
#   inflating: ./data/967.jpg
#   inflating: ./data/967.txt
#   inflating: ./data/968.jpg
#   inflating: ./data/968.txt
#   inflating: ./data/969.jpg
#   inflating: ./data/969.txt
#   inflating: ./data/97.jpg
#   inflating: ./data/97.txt
#   inflating: ./data/970.jpg
#   inflating: ./data/970.txt
#   inflating: ./data/971.jpg
#   inflating: ./data/971.txt
#   inflating: ./data/972.jpg
#   inflating: ./data/972.txt
#   inflating: ./data/973.jpg
#   inflating: ./data/973.txt
#   inflating: ./data/974.jpg
#   inflating: ./data/974.txt
#   inflating: ./data/975.jpg
#   inflating: ./data/975.txt
#   inflating: ./data/976.jpg
#   inflating: ./data/976.txt
#   inflating: ./data/977.jpg
#   inflating: ./data/977.txt
#   inflating: ./data/978.jpg
#   inflating: ./data/978.txt
#   inflating: ./data/979.jpg
#   inflating: ./data/979.txt
#   inflating: ./data/98.jpg
#   inflating: ./data/98.txt
#   inflating: ./data/980.jpg
#   inflating: ./data/980.txt
#   inflating: ./data/981.jpg
#   inflating: ./data/981.txt
#   inflating: ./data/982.jpg
#   inflating: ./data/982.txt
#   inflating: ./data/983.jpg
#   inflating: ./data/983.txt
#   inflating: ./data/984.jpg
#   inflating: ./data/984.txt
#   inflating: ./data/985.jpg
#   inflating: ./data/985.txt
#   inflating: ./data/986.jpg
#   inflating: ./data/986.txt
#   inflating: ./data/987.jpg
#   inflating: ./data/987.txt
#   inflating: ./data/988.jpg
#   inflating: ./data/988.txt
#   inflating: ./data/989.jpg
#   inflating: ./data/989.txt
#   inflating: ./data/99.jpg
#   inflating: ./data/99.txt
#   inflating: ./data/990.jpg
#   inflating: ./data/990.txt
#   inflating: ./data/991.jpg
#   inflating: ./data/991.txt
#   inflating: ./data/992.jpg
#   inflating: ./data/992.txt
#   inflating: ./data/993.jpg
#   inflating: ./data/993.txt
#   inflating: ./data/994.jpg
#   inflating: ./data/994.txt
#   inflating: ./data/995.jpg
#   inflating: ./data/995.txt
#   inflating: ./data/996.jpg
#   inflating: ./data/996.txt
#   inflating: ./data/997.jpg
#   inflating: ./data/997.txt
#   inflating: ./data/998.jpg
#   inflating: ./data/998.txt
#   inflating: ./data/999.jpg
#   inflating: ./data/999.txt

# %% [markdown]
# 读取数据，记录训练集与测试集的id，将label转化成0、1、2三类，对应积极、中立、消极三种情感

# %%
with open('./train.txt', 'r') as f:
  lines = f.readlines()

train_set = []

for line in lines[1:]:
  data = {}
  line = line.replace('\n','')
  guid, tag = line.split(',')
  if tag == 'positive':
    label = 0
  elif tag == 'neutral':
    label = 1
  else:
    label = 2
  data['guid'] = guid
  data['label'] = label
  train_set.append(data)

# print(len(train_set)) # 4000
# print(train_set)

# %%
with open('./test_without_label.txt', 'r') as f:
  lines = f.readlines()

test_set = []
for line in lines[1:]:
  data = {}
  data['guid'] = line.split(',')[0]
  test_set.append(data)

# %% [markdown]
# 对所有图像的大小进行统一，规范至(224, 224, 3)，符合ResNet18的输入大小
#
# 读取并存储文本至数据集中，无法解码的字符使用ignore进行忽略

# %%
def data_process(dataset):
  for data in dataset:
    guid = data['guid']
    image_path = './data/' + guid + '.jpg'
    image = Image.open(image_path).convert('RGB')
    array = np.array(image.resize((224, 224)))
    data['image'] = array.reshape((3, 224, 224))

    text_path = './data/' + guid + '.txt'
    f = open(text_path, 'r', errors='ignore')
    lines = f.readlines()
    # print(lines)
    text = ''
    for line in lines:
      text += line
    data['text'] = text

# %%
data_process(train_set)
data_process(test_set)

# %% [markdown]
# 划分数据集，验证集采用和测试集相近的数目（500条）

# %%
train_set_num = 3500
valid_set_num = 500
train_set, valid_set = random_split(train_set, [train_set_num, valid_set_num])

# %% [markdown]
# ## 图像分类器
#
# 图像分类采用的ResNet18模型，在第三次实验中表现最佳
#
# 定义残差块ResBlock和ShorcutResBlock，前者不改变通道数，后者会改变通道数：

# %%
class ResBlock(nn.Module):
  def __init__(self, input_channel, output_channel):
    super(ResBlock, self).__init__()
    self.conv1 = nn.Conv2d(input_channel, output_channel, kernel_size=(3, 3), padding=1, stride=1)
    self.bn1 = nn.BatchNorm2d(output_channel)
    self.conv2 = nn.Conv2d(output_channel, output_channel, kernel_size=(3, 3), padding=1, stride=1)
    self.bn2 = nn.BatchNorm2d(output_channel)

  def forward(self, x):
    output = self.conv1(x)
    output = self.bn1(output)
    output = F.relu(output)
    output = self.conv2(x)
    output = self.bn2(output)
    output = F.relu(output + x)
    return output


class ShortcutResBlock(nn.Module):
  def __init__(self, input_channel, output_channel):
    super(ShortcutResBlock, self).__init__()
    self.conv1 = nn.Conv2d(input_channel, output_channel, kernel_size=(1, 1), stride=2)
    self.bn1 = nn.BatchNorm2d(output_channel)
    self.conv2 = nn.Conv2d(input_channel, output_channel, kernel_size=(3, 3), padding=1, stride=2)
    self.bn2 = nn.BatchNorm2d(output_channel)
    self.conv3 = nn.Conv2d(output_channel, output_channel, kernel_size=(3, 3), padding=1, stride=1)
    self.bn3 = nn.BatchNorm2d(output_channel)

  def forward(self, x):
    output1 = self.conv1(x)
    output1 = self.bn1(output1)
    output2 = self.conv2(x)
    output2 = self.bn2(output2)
    output2 = F.relu(output2)
    output2 = self.conv3(output2)
    output2 = self.bn3(output2)
    output = F.relu(output1 + output2)
    return output

# %% [markdown]
# 定义完整的ResNet18：

# %%
class ResNet18(nn.Module):
  def __init__(self):
    super(ResNet18, self).__init__()
    self.conv1 = nn.Conv2d(3, 64, kernel_size=(7, 7), padding=3, stride=2)
    self.bn1 = nn.BatchNorm2d(64)
    self.pool1 = nn.MaxPool2d(kernel_size=(3, 3), padding=1, stride=2)
    self.res1 = ResBlock(64, 64)
    self.res2 = ResBlock(64, 64)
    self.shortcut1 = ShortcutResBlock(64, 128)
    self.res3 = ResBlock(128, 128)
    self.shortcut2 = ShortcutResBlock(128, 256)
    self.res4 = ResBlock(256, 256)
    self.shortcut3 = ShortcutResBlock(256, 512)
    self.res5 = ResBlock(512, 512)
    self.pool2 = nn.AvgPool2d((7, 7))
    self.dropout = nn.Dropout(0)
    self.fc = nn.Linear(512, 3)

  def forward(self, x):
    output = self.conv1(x)
    output = self.bn1(output)
    output = self.pool1(F.relu(output))
    output = self.res1(output)
    output = self.res2(output)
    output = self.shortcut1(output)
    output = self.res3(output)
    output = self.shortcut2(output)
    output = self.res4(output)
    output = self.shortcut3(output)
    output = self.res5(output)
    output = self.pool2(output)
    output = torch.flatten(output, 1)
    output = self.fc(output)
    return output

# %% [markdown]
# 验证一下图像分类器单独分类的性能
#
# 使用TensorDataset生成训练图像分类器的数据集：

# %%
image_train = []
image_train_labels = []
image_valid = []
image_valid_labels = []

for data in train_set:
  image_train.append(data['image'])
  image_train_labels.append(data['label'])

for data in valid_set:
  image_valid.append(data['image'])
  image_valid_labels.append(data['label'])

image_train = torch.from_numpy(np.array(image_train))
image_train_labels = torch.from_numpy(np.array(image_train_labels))
image_valid = torch.from_numpy(np.array(image_valid))
image_valid_labels = torch.from_numpy(np.array(image_valid_labels))

train_loader = DataLoader(TensorDataset(image_train, image_train_labels), batch_size=100, shuffle=True)
valid_loader = DataLoader(TensorDataset(image_valid, image_valid_labels), batch_size=50)

# %% [markdown]
# 训练图像分类器，学习率5e-6，训练50个epoch

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
image_classifier = ResNet18()
image_classifier.to(device)

epoch_num = 50
learning_rate = 1e-6
total_step = epoch_num * len(train_loader)

optimizer = AdamW(image_classifier.parameters(), lr=learning_rate, eps=1e-8)
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0.1*total_step, num_training_steps=total_step)


# optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)
criterion = nn.CrossEntropyLoss()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
for epoch in range(epoch_num):
  running_loss = 0
  for i, data in enumerate(train_loader):
    inputs, labels = data
    inputs = inputs.float()
    inputs = inputs.to(device)
    labels = labels.to(device)
    # print(inputs.shape)
    outputs = image_classifier(inputs)
    # print(outputs.shape)
    loss = criterion(outputs, labels)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    scheduler.step()
    running_loss += loss.item()
  print('epoch: %d  loss: %.3f' % (epoch+1, running_loss / 35))
  running_loss = 0
# Out:
# epoch: 1  loss: 0.938
# epoch: 2  loss: 0.928
# epoch: 3  loss: 0.915
# epoch: 4  loss: 0.905
# epoch: 5  loss: 0.896
# epoch: 6  loss: 0.889
# epoch: 7  loss: 0.882
# epoch: 8  loss: 0.878
# epoch: 9  loss: 0.872
# epoch: 10  loss: 0.870
# epoch: 11  loss: 0.865
# epoch: 12  loss: 0.862
# epoch: 13  loss: 0.858
# epoch: 14  loss: 0.856
# epoch: 15  loss: 0.854
# epoch: 16  loss: 0.850
# epoch: 17  loss: 0.849
# epoch: 18  loss: 0.844
# epoch: 19  loss: 0.843
# epoch: 20  loss: 0.843
# epoch: 21  loss: 0.839
# epoch: 22  loss: 0.837
# epoch: 23  loss: 0.834
# epoch: 24  loss: 0.830
# epoch: 25  loss: 0.832
# epoch: 26  loss: 0.829
# epoch: 27  loss: 0.827
# epoch: 28  loss: 0.823
# epoch: 29  loss: 0.822
# epoch: 30  loss: 0.822
# epoch: 31  loss: 0.819
# epoch: 32  loss: 0.817
# epoch: 33  loss: 0.816
# epoch: 34  loss: 0.814
# epoch: 35  loss: 0.814
# epoch: 36  loss: 0.812
# epoch: 37  loss: 0.812
# epoch: 38  loss: 0.811
# epoch: 39  loss: 0.808
# epoch: 40  loss: 0.809
# epoch: 41  loss: 0.807
# epoch: 42  loss: 0.808
# epoch: 43  loss: 0.806
# epoch: 44  loss: 0.803
# epoch: 45  loss: 0.806
# epoch: 46  loss: 0.804
# epoch: 47  loss: 0.806
# epoch: 48  loss: 0.805
# epoch: 49  loss: 0.804
# epoch: 50  loss: 0.803

# %% [markdown]
# 在验证集上测试参数训练的效果：

# %%
correct_num = 0
total_num = 0
with torch.no_grad():
  for data in valid_loader:
    inputs, answers = data
    inputs = inputs.float()
    inputs = inputs.to(device)
    answers = answers.to(device)
    outputs = image_classifier(inputs)
    _, predicted = torch.max(outputs.data, 1)
    for i in range(len(predicted.tolist())):
      total_num += answers.size(0)
      correct_num += (predicted == answers).sum().item()

print('Training Accuracy: %.3f%%' % (100 * correct_num / total_num))
# Out:
# Training Accuracy: 60.200%

# %% [markdown]
# 图像分类器在图像数据集上的正确率能够达到50%左右,最高能够到达60%

# %% [markdown]
# ## 文本分类器
#
# 使用预训练模型bert-base-chinese

# %%
checkpoint = 'bert-base-chinese'
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
bert_model = AutoModel.from_pretrained(checkpoint)
# bert_model.to(device)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/624 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/110k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/269k [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/412M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-chinese were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# 创建文本分类器模型，在Bert的基础上增添一个线性层

# %%
class TextClassifier(nn.Module):
  def __init__(self):
    super(TextClassifier, self).__init__()
    self.model = bert_model
    self.model = self.model.to(device)
    self.dropout = nn.Dropout(0)
    # self.model.to(device)
    self.fc = nn.Linear(768, 3)

  def forward(self, x, attn_mask=None):
    x = x.to(device)
    attn_mask = attn_mask.to(device)
    output = self.model(x, attention_mask=attn_mask)
    # output = output.to(device)
    output = output[1]
    output = torch.flatten(output, 1)
    output = self.fc(output)
    return output

# %% [markdown]
# 验证Bert在文本分类上的性能
#
# 对输入数据进行tokenize，统一长度，生成注意力分数

# %%
text_train = []
text_valid = []

for data in train_set:
  tokenized_text = tokenizer(data['text'], max_length=128, padding='max_length', truncation=True)
  # tokenized_text['input_ids'] = torch.from_numpy(np.array(tokenized_text['input_ids']))
  tokenized_text['label'] = data['label']
  text_train.append(tokenized_text)

for data in valid_set:
  tokenized_text = tokenizer(data['text'], max_length=128, padding='max_length', truncation=True)
  tokenized_text['label'] = data['label']
  text_valid.append(tokenized_text)

# %% [markdown]
# 重载Dataset类，便于生成Dataloader

# %%
class TextDataset(Dataset):
  def __init__(self, data):
    super(TextDataset, self).__init__()
    self.data = data

  def __len__(self):
    return len(self.data)

  def __getitem__(self, idx):
    input_ids = self.data[idx]['input_ids']
    attn_mask = self.data[idx]['attention_mask']
    label = self.data[idx]['label']
    return input_ids, attn_mask, label

train_loader = DataLoader(TextDataset(text_train), batch_size=25, shuffle=True)
valid_loader = DataLoader(TextDataset(text_valid), batch_size=25)

# %%
text_classifier = TextClassifier()
text_classifier.to(device)
# classifier.model.to(device)

epoch_num = 20
learning_rate = 1e-5
total_step = epoch_num * len(train_loader)

optimizer = AdamW(text_classifier.parameters(), lr=learning_rate, eps=1e-8)
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0.1*total_step, num_training_steps=total_step)

criterion = nn.CrossEntropyLoss()

# %%
# classifier.train()

for epoch in range(epoch_num):
  running_loss = 0
  for i, data in enumerate(train_loader):
    input_ids, attn_mask, labels = data
    input_ids = torch.tensor([item.numpy() for item in input_ids])
    attn_mask = torch.tensor([item.numpy() for item in attn_mask])
    input_ids = input_ids.T
    attn_mask = attn_mask.T
    # labels = torch.tensor([item.numpy() for item in labels])
    input_ids = input_ids.to(device)
    attn_mask = attn_mask.to(device)
    labels = labels.to(device)

    # print(input_ids.shape)
    # print(attn_mask.shape)

    outputs = text_classifier(input_ids, attn_mask)
    # print(outputs.shape)
    loss = criterion(outputs, labels)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    scheduler.step()

    running_loss += loss.item()
  print('epoch: %d  loss: %.3f' % (epoch+1, running_loss/140))
  running_loss = 0
# Out:
# <ipython-input-23-769dc7bbcb1e>:7: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:245.)
#   input_ids = torch.tensor([item.numpy() for item in input_ids])
# epoch: 1  loss: 0.929
# epoch: 2  loss: 0.858
# epoch: 3  loss: 0.756
# epoch: 4  loss: 0.547
# epoch: 5  loss: 0.324
# epoch: 6  loss: 0.200
# epoch: 7  loss: 0.140
# epoch: 8  loss: 0.105
# epoch: 9  loss: 0.084
# epoch: 10  loss: 0.067
# epoch: 11  loss: 0.062
# epoch: 12  loss: 0.058
# epoch: 13  loss: 0.051
# epoch: 14  loss: 0.045
# epoch: 15  loss: 0.042
# epoch: 16  loss: 0.040
# epoch: 17  loss: 0.039
# epoch: 18  loss: 0.036
# epoch: 19  loss: 0.035
# epoch: 20  loss: 0.034

# %%
correct_num = 0
total_num = 0
with torch.no_grad():
  for data in valid_loader:
    input_ids, attn_mask, labels = data
    input_ids = torch.tensor([item.numpy() for item in input_ids])
    input_ids = input_ids.T
    attn_mask = torch.tensor([item.numpy() for item in attn_mask])
    attn_mask = attn_mask.T
    input_ids = input_ids.to(device)
    attn_mask = attn_mask.to(device)
    labels = labels.to(device)

    outputs = text_classifier(input_ids, attn_mask)
    _, predicted = torch.max(outputs.data, 1)
    for i in range(len(predicted.tolist())):
      total_num += labels.size(0)
      correct_num += (predicted == labels).sum().item()

print('Training Accuracy: %.3f%%' % (100 * correct_num / total_num))
# Out:
# Training Accuracy: 62.800%

# %% [markdown]
# 基于bert的文本分类器在数据集上的正确率能够到达60%

# %% [markdown]
# ## 融合模型
#
# 定义完整的Dataset，输入时向文本分类器提供文本，图片分类器提供图片

# %%
class MultimodalDataset(Dataset):
  def __init__(self, data):
    super(MultimodalDataset, self).__init__()
    self.data = data

  def __len__(self):
    return len(self.data)

  def __getitem__(self, idx):
    guid = self.data[idx]['guid']
    input_ids = torch.tensor(self.data[idx]['input_ids'])
    attn_mask = torch.tensor(self.data[idx]['attn_mask'])
    image = torch.tensor(self.data[idx]['image'])
    label = self.data[idx].get('label')
    if label is None:
      label = -100
    label = torch.tensor(label)
    return guid, input_ids, attn_mask, image, label

# %%
def dataset_process(dataset):
  for data in dataset:
    tokenized_text = tokenizer(data['text'], max_length=128, padding='max_length', truncation=True)
    data['input_ids'] = tokenized_text['input_ids']
    data['attn_mask'] = tokenized_text['attention_mask']

# %%
dataset_process(train_set)
dataset_process(valid_set)
dataset_process(test_set)

# %%
train_loader = DataLoader(MultimodalDataset(train_set), batch_size=25, shuffle=True)
valid_loader = DataLoader(MultimodalDataset(valid_set), batch_size=25)
test_loader = DataLoader(MultimodalDataset(test_set), batch_size=25)

# %% [markdown]
# 构建完整的融合模型类，文本分类器的输出结果与图像分类器的输出结果拼接，经过线性层分类后输出
#
# 两个分类器的输出shape均为为(batch_size, output_features)
#
# 对拼接后的特征向量，先进入一个线性层，使模型学习两个特征向量之间的关系
#
# 最后进入分类层，输出结果

# %%
class MultimodalModel(nn.Module):
  def __init__(self, image_classifier, text_classifier, output_features, image_weight=0.5, text_weight=0.5):
    super(MultimodalModel, self).__init__()
    self.image_classifier = image_classifier
    self.text_classifier = text_classifier
    # 将最后的全连接层删除
    self.image_classifier.fc = nn.Sequential()  # (batch_num, 512)
    self.text_classifier.fc = nn.Sequential()    # (batch_num, 768)
    # 文本特征向量和图片特征向量的权重, 默认均为0.5
    self.image_weight = image_weight
    self.text_weight = text_weight
    self.fc1 = nn.Linear((512+768), output_features)
    self.fc2 = nn.Linear(output_features, 3)

  def forward(self, input_ids, attn_mask, image):
    image_output = self.image_classifier(image)
    text_output = self.text_classifier(input_ids, attn_mask)
    output = torch.cat([image_output, text_output], dim=-1)
    output = self.fc1(output)
    output = self.fc2(output)
    return output

# %% [markdown]
# 实例化时使用先前训练完成的模型，在各自数据集上的分类效果较好，提取出的特征向量表现相较于初始化的模型也更优

# %%
multimodal_model = MultimodalModel(image_classifier=image_classifier, text_classifier=text_classifier, output_features=100, image_weight=0.5, text_weight=0.5)
multimodal_model.to(device)

epoch_num = 10
learning_rate = 1e-5
total_step = epoch_num * len(train_loader)

optimizer = AdamW(multimodal_model.parameters(), lr=learning_rate, eps=1e-8)
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0.1*total_step, num_training_steps=total_step)
criterion = nn.CrossEntropyLoss()

# %%
for epoch in range(epoch_num):
  running_loss = 0
  for i, data in enumerate(train_loader):
    _, input_ids, attn_mask, image, label = data
    input_ids = input_ids.to(device)
    attn_mask = attn_mask.to(device)
    image = image.to(device)
    image = image.float()
    label = label.to(device)

    outputs = multimodal_model(input_ids=input_ids, attn_mask=attn_mask, image=image)
    # print(outputs.shape)
    loss = criterion(outputs, label)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    scheduler.step()

    running_loss += loss.item()
  print('epoch: %d  loss: %.3f' % (epoch+1, running_loss/140))
  running_loss = 0
# Out:
# epoch: 1  loss: 0.609
# epoch: 2  loss: 0.184
# epoch: 3  loss: 0.113
# epoch: 4  loss: 0.078
# epoch: 5  loss: 0.055
# epoch: 6  loss: 0.046
# epoch: 7  loss: 0.040
# epoch: 8  loss: 0.035
# epoch: 9  loss: 0.033
# epoch: 10  loss: 0.030

# %%
correct_num = 0
total_num = 0
with torch.no_grad():
  for data in valid_loader:
    _, input_ids, attn_mask, image, label = data
    input_ids = input_ids.to(device)
    attn_mask = attn_mask.to(device)
    image = image.to(device)
    image = image.float()
    label = label.to(device)

    outputs = multimodal_model(input_ids=input_ids, attn_mask=attn_mask, image=image)
    _, predicted = torch.max(outputs.data, 1)
    for i in range(len(predicted.tolist())):
      total_num += label.size(0)
      correct_num += (predicted == label).sum().item()

print('Training Accuracy: %.3f%%' % (100 * correct_num / total_num))
# Out:
# Training Accuracy: 63.600%

# %%
test_dict = {}
with torch.no_grad():
  for data in test_loader:
    guid, input_ids, attn_mask, image, label = data
    input_ids = input_ids.to(device)
    attn_mask = attn_mask.to(device)
    image = image.to(device)
    image = image.float()
    label = label.to(device)

    outputs = multimodal_model(input_ids=input_ids, attn_mask=attn_mask, image=image)
    _, predicted = torch.max(outputs.data, 1)
    predicted = predicted.tolist()
    for i in range(len(predicted)):
      id = guid[i]
      test_dict[id] = predicted[i]

# %% [markdown]
# 将分类结果重新写入文件

# %%
with open('./test_without_label.txt', 'r') as f:
  lines = f.readlines()

f1 = open('./test.txt', 'w')
f1.write(lines[0])

for line in lines[1:]:
  # print(line)
  guid = line.split(',')[0]
  f1.write(guid)
  f1.write(',')
  label = test_dict[guid]
  if label == 0:
    f1.write('positive\n')
  elif label == 1:
    f1.write('neutral\n')
  else:
    f1.write('negative\n')
